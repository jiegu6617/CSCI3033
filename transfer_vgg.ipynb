# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import random
import numpy as np
import pandas as pd 
from skimage import io
from skimage import color
from PIL import Image
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
from dask.array.image import imread
# from dask import bag, threaded
from dask.diagnostics import ProgressBar
import cv2
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")



import keras
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
from keras.layers import Flatten,Dropout
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image 
from keras.layers.normalization import BatchNormalization
from keras import optimizers

# %%
driver_details = pd.read_csv('/content/drive/MyDrive/deep_learning_project/input/driver_imgs_list.csv',na_values='na')
print(driver_details.head(5))
# Out:
#   subject classname            img
# 0    p002        c0  img_44733.jpg
# 1    p002        c0  img_72999.jpg
# 2    p002        c0  img_25094.jpg
# 3    p002        c0  img_69092.jpg
# 4    p002        c0  img_92629.jpg

# %%
X_train=np.load('/content/drive/MyDrive/deep_learning_project/X_train.npy')
X_test=np.load('/content/drive/MyDrive/deep_learning_project/X_test.npy')
y_train=np.load('/content/drive/MyDrive/deep_learning_project/y_train.npy')
y_test=np.load('/content/drive/MyDrive/deep_learning_project/y_test.npy')

# %%
X_train.shape
# Out:
# (17263, 224, 224, 3)

# %%
from keras.layers import Input
vgg16_input = Input(shape = (224, 224, 3), name = 'Image_input')


## The VGG model

from keras.applications.vgg16 import VGG16, preprocess_input

#Get back the convolutional part of a VGG network trained on ImageNet
model_vgg16_conv = VGG16(weights='imagenet', include_top=False, input_tensor = vgg16_input)
model_vgg16_conv.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Image_input (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.models import Model


output_vgg16_conv = model_vgg16_conv(vgg16_input)

#Add the fully-connected layers 

x = Flatten(name='flatten')(output_vgg16_conv)
# x = Dense(4096, activation='relu', name='fc1')(x)
# x = Dense(4096, activation='relu', name='fc2')(x)
x = Dense(10, activation='softmax', name='predictions')(x)

vgg16_pretrained = Model(vgg16_input,x)
vgg16_pretrained.summary()

# Compile CNN model
sgd = optimizers.SGD(lr = 0.001)
vgg16_pretrained.compile(loss='categorical_crossentropy',optimizer = sgd,metrics=['accuracy'])
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Image_input (InputLayer)     [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# predictions (Dense)          (None, 10)                250890
# =================================================================
# Total params: 14,965,578
# Trainable params: 14,965,578
# Non-trainable params: 0
# _________________________________________________________________

# %%
list(range(3))
# Out:
# [0, 1, 2]

# %%
import random
index=list(range(len(y_train)))
idx=random.sample(index,10000)
X_train=X_train[idx]
y_train=y_train[idx]
X_train.shape
# Out:
# (10000, 224, 224, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint,EarlyStopping

checkpointer = ModelCheckpoint('vgg_weights_aug_setval_sgd.hdf5', verbose=1, save_best_only=True)
earlystopper = EarlyStopping(monitor='val_loss', patience=10, verbose=1)


datagen = ImageDataGenerator(
    height_shift_range=0.5,
    width_shift_range = 0.5,
    zoom_range = 0.5,
    rotation_range=30
        )

# Fits the model on batches with real-time data augmentation:
vgg16_model = vgg16_pretrained.fit_generator(datagen.flow(X_train, y_train, batch_size = 64),steps_per_epoch = len(X_train) / 64, callbacks=[checkpointer, earlystopper],
                                                            epochs = 25, verbose = 1, validation_data = (X_test, y_test))
# Out:
# Epoch 1/25
# 156/156 [==============================] - 128s 817ms/step - loss: 2.2534 - accuracy: 0.1227 - val_loss: 2.2633 - val_accuracy: 0.0984
#
# Epoch 00001: val_loss improved from inf to 2.26333, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 2/25
# 156/156 [==============================] - 128s 818ms/step - loss: 2.2390 - accuracy: 0.1326 - val_loss: 2.2212 - val_accuracy: 0.1380
#
# Epoch 00002: val_loss improved from 2.26333 to 2.22118, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 3/25
# 156/156 [==============================] - 127s 814ms/step - loss: 2.2216 - accuracy: 0.1476 - val_loss: 2.2296 - val_accuracy: 0.1104
#
# Epoch 00003: val_loss did not improve from 2.22118
# Epoch 4/25
# 156/156 [==============================] - 129s 823ms/step - loss: 2.1827 - accuracy: 0.1773 - val_loss: 2.1550 - val_accuracy: 0.1894
#
# Epoch 00004: val_loss improved from 2.22118 to 2.15496, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 5/25
# 156/156 [==============================] - 129s 822ms/step - loss: 2.1057 - accuracy: 0.2185 - val_loss: 2.0832 - val_accuracy: 0.2772
#
# Epoch 00005: val_loss improved from 2.15496 to 2.08316, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 6/25
# 156/156 [==============================] - 128s 817ms/step - loss: 2.0233 - accuracy: 0.2437 - val_loss: 1.8560 - val_accuracy: 0.2880
#
# Epoch 00006: val_loss improved from 2.08316 to 1.85602, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 7/25
# 156/156 [==============================] - 127s 811ms/step - loss: 1.8883 - accuracy: 0.2993 - val_loss: 1.7582 - val_accuracy: 0.3435
#
# Epoch 00007: val_loss improved from 1.85602 to 1.75815, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 8/25
# 156/156 [==============================] - 128s 819ms/step - loss: 1.7202 - accuracy: 0.3675 - val_loss: 1.3201 - val_accuracy: 0.5161
#
# Epoch 00008: val_loss improved from 1.75815 to 1.32005, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 9/25
# 156/156 [==============================] - 127s 815ms/step - loss: 1.5480 - accuracy: 0.4455 - val_loss: 1.0129 - val_accuracy: 0.6497
#
# Epoch 00009: val_loss improved from 1.32005 to 1.01293, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 10/25
# 156/156 [==============================] - 128s 821ms/step - loss: 1.3303 - accuracy: 0.5397 - val_loss: 1.0670 - val_accuracy: 0.6741
#
# Epoch 00010: val_loss did not improve from 1.01293
# Epoch 11/25
# 156/156 [==============================] - 127s 810ms/step - loss: 1.1261 - accuracy: 0.6097 - val_loss: 0.7876 - val_accuracy: 0.7425
#
# Epoch 00011: val_loss improved from 1.01293 to 0.78761, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 12/25
# 156/156 [==============================] - 128s 821ms/step - loss: 0.9596 - accuracy: 0.6689 - val_loss: 0.9365 - val_accuracy: 0.7246
#
# Epoch 00012: val_loss did not improve from 0.78761
# Epoch 13/25
# 156/156 [==============================] - 128s 816ms/step - loss: 0.8806 - accuracy: 0.7009 - val_loss: 0.6426 - val_accuracy: 0.8048
#
# Epoch 00013: val_loss improved from 0.78761 to 0.64258, saving model to vgg_weights_aug_setval_sgd.hdf5
# Epoch 14/25
# 156/156 [==============================] - 127s 815ms/step - loss: 0.7981 - accuracy: 0.7209 - val_loss: 0.9469 - val_accuracy: 0.7607
#
# Epoch 00014: val_loss did not improve from 0.64258
# Epoch 15/25
# 156/156 [==============================] - 126s 808ms/step - loss: 0.7566 - accuracy: 0.7418 - val_loss: 0.7359 - val_accuracy: 0.7913
#
# Epoch 00015: val_loss did not improve from 0.64258
# Epoch 16/25
# 156/156 [==============================] - 127s 810ms/step - loss: 0.7000 - accuracy: 0.7602 - val_loss: 0.8889 - val_accuracy: 0.7548
#
# Epoch 00016: val_loss did not improve from 0.64258
# Epoch 17/25
# 156/156 [==============================] - 127s 810ms/step - loss: 0.6441 - accuracy: 0.7798 - val_loss: 1.3290 - val_accuracy: 0.7299
#
# Epoch 00017: val_loss did not improve from 0.64258
# Epoch 18/25
# 156/156 [==============================] - 126s 808ms/step - loss: 0.6269 - accuracy: 0.7825 - val_loss: 0.7973 - val_accuracy: 0.7851
#
# Epoch 00018: val_loss did not improve from 0.64258
# Epoch 19/25
# 156/156 [==============================] - 127s 814ms/step - loss: 0.5975 - accuracy: 0.7914 - val_loss: 0.7815 - val_accuracy: 0.8018
#
# Epoch 00019: val_loss did not improve from 0.64258
# Epoch 20/25
# 156/156 [==============================] - 126s 808ms/step - loss: 0.5624 - accuracy: 0.8064 - val_loss: 0.7847 - val_accuracy: 0.8103
#
# Epoch 00020: val_loss did not improve from 0.64258
# Epoch 21/25
# 156/156 [==============================] - 126s 807ms/step - loss: 0.5505 - accuracy: 0.8089 - val_loss: 1.1597 - val_accuracy: 0.7443
#
# Epoch 00021: val_loss did not improve from 0.64258
# Epoch 22/25
# 156/156 [==============================] - 127s 810ms/step - loss: 0.5442 - accuracy: 0.8121 - val_loss: 1.5997 - val_accuracy: 0.7190
#
# Epoch 00022: val_loss did not improve from 0.64258
# Epoch 23/25
# 156/156 [==============================] - 126s 806ms/step - loss: 0.5169 - accuracy: 0.8207 - val_loss: 0.9230 - val_accuracy: 0.8045
#
# Epoch 00023: val_loss did not improve from 0.64258
# Epoch 00023: early stopping

# %%
fig, axes = plt.subplots(1, 2, figsize = (10, 5))
axes[0].plot(range(1, len(vgg16_pretrained.history.history['accuracy']) + 1), vgg16_pretrained.history.history['accuracy'], linestyle = 'solid', marker = 'o', color = 'crimson', label = 'Training Accuracy')
axes[0].plot(range(1, len(vgg16_pretrained.history.history['val_accuracy']) + 1), vgg16_pretrained.history.history['val_accuracy'], linestyle = 'solid', marker = 'o', color = 'dodgerblue', label = 'Testing Accuracy')
axes[0].set_xlabel('Epochs', fontsize = 14)
axes[0].set_ylabel('Accuracy',fontsize = 14)
axes[0].set_title('CNN Dropout Accuracy Trainig VS Testing', fontsize = 14)
axes[0].legend(loc = 'best')
axes[1].plot(range(1, len(vgg16_pretrained.history.history['loss']) + 1), vgg16_pretrained.history.history['loss'], linestyle = 'solid', marker = 'o', color = 'crimson', label = 'Training Loss')
axes[1].plot(range(1, len(vgg16_pretrained.history.history['val_loss']) + 1), vgg16_pretrained.history.history['val_loss'], linestyle = 'solid', marker = 'o', color = 'dodgerblue', label = 'Testing Loss')
axes[1].set_xlabel('Epochs', fontsize = 14)
axes[1].set_ylabel('Loss',fontsize = 14)
axes[1].set_title('CNN Dropout Loss Trainig VS Testing', fontsize = 14)
axes[1].legend(loc = 'best')
